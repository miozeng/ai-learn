# %% [markdown]
# ## 推荐系统实践
# 使用数据天池新人实战赛之[离线赛]
# 我们有用户在商品全集上的移动端行为数据tianchi_fresh_comp_train_user
#
#     user_id 用户标识
#     item_id商品标识
#     behavior_type 用户对商品的行为类型包括浏览、收藏、加购物车、购买，对应取值分别是1、2、3、4。
#     user_geohash用户位置的空间标识，可以为空由经纬度通过保密的算法生成
#     item_category商品分类标识
#     time行为时间

# %% [markdown]
# 计划步骤：
#
#     1.加载和处理数据
#     2.根据用户得相关属性，计算用户相似度（深度学习）
#     3.根据商品得相关属性，计算商品得相似度（深度学习）
#     4.根据用户推荐商品（UCF OR ICF）

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras
# 导入辅助库
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import datetime
import sys
import time

# %% [markdown]
# ### 1.处理数据

# %% [markdown]
# #### 1.1 读取csv

# %% [markdown]
# ##### 读取方式一

# %%
filenames = ["../data/user/test_user.csv"]
record_defaults = [tf.int32,tf.int32,tf.int32,tf.string,tf.int32,tf.string]  # Eight required float columns
dataset = tf.data.experimental.CsvDataset(filenames, record_defaults)

# %%
def _read_py_function(user_id,item_id,behavior_type,user_geohash,item_category,time):
    #time.toString()
    #time2 = tf.as_string(time)
    #time2 =tf.strings.as_string(time)
    #action_time = datetime.datetime.strptime(time,"%Y-%m-%d %H")
    #end_date = datetime.datetime(2014,12,19,0,0,0)
    #cdate = end_date - action_time 
    #print(cdate.days)
    return user_id,item_id,behavior_type,user_geohash,item_category,time

dataset = dataset.map(_read_py_function)
# Out:
# WARNING:tensorflow:Entity <function _read_py_function at 0x000002E8DA121730> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <function _read_py_function at 0x000002E8DA121730> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4

# %% [markdown]
# ##### 读取方式2

# %%
user_data = pd.read_csv("../data/user/test_user.csv")
def date_cal(time):
    action_time = datetime.datetime.strptime(time,"%Y-%m-%d %H")
    end_date = datetime.datetime(2014,12,19,0,0,0)
    cdate = end_date - action_time 
    return cdate.days
user_data['days'] = list(map(date_cal, user_data['time']))
# user_id,item_id,behavior_type,user_geohash,item_category,time
dataset = tf.data.Dataset.from_tensor_slices([user_data["user_id"],user_data["item_id"],user_data["behavior_type"],
                                             user_data["item_category"],user_data["days"]])

# %% [markdown]
# ### 2.建立模型

# %%
#3.1构建模型网络层
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
#3.2编译模型
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### 3.训练模型
# https://blog.csdn.net/chengcheng1394/article/details/78820529

# %%
model.fit(train_images, train_labels, epochs=5)

# %%
#1加载数据https://blog.csdn.net/chengcheng1394/article/details/78820529
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
#2处理数据
train_images = train_images / 255.0

test_images = test_images / 255.0

#3建立模型
#3.1构建模型网络层
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
#3.2编译模型
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

#4训练模型
model.fit(train_images, train_labels, epochs=5)

#5评估模型
test_loss, test_acc = model.evaluate(test_images, test_labels)
#6模型预测
print('Test accuracy:', test_acc)

predictions = model.predict(test_images)

predictions[0]
# Out:
# ...
# 4423680/4422102 [==============================] - 12s 3us/step
# Train on 60000 samples
# Epoch 1/5
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002E8B4E48488> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x000002E8B4E48488> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.4960 - accuracy: 0.8249
# Epoch 2/5
# ...
